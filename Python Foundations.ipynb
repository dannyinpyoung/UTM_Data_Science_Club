# %% [markdown]
# # RESOURCES
#
# [A WhirlWind Tour of Python](https://nbviewer.jupyter.org/github/jakevdp/WhirlwindTourOfPython/blob/master/Index.ipynb): For a book to accompany the lesson.
#
# [For Python Dcoumentation](https://docs.python.org/3/library/index.html)
#
#
#
#
# *These are Notes*
# # Largest Heading
# ## Sub heading
# ### sub sub heading ETC
# __here is another example__
#
# `for code use back tick`
#
# `back tick` is different from 'Apostrophes'
#
# 3 * for a horizontal line
#
# Using  `<br>` gets you a line break <br> here we are after the line break.
#
# ***
#
# ## Lists
# * Unordered List Item 1
#     * sub bullet item 1
#
# *or use*
#
# 1. Ordered List Item 1
# 2. Ordered List Item 2
#     1. Sub Ordered List Item 1
#     2. Sub Ordered List Item 2
# ***
#
# ## Images
# Use `![title](img/picture.png)`.
# The first bracket represents the image name and the parantheses will fill in the path or url of the image.
# ***
#
# ## Links (External and Internal)
# Use `[link text](http://url):`. <br>
# EG: Click on the following [link](https://www.codeacademy.com/). <br>
# Adding internal sections are even easier to use: <br>
# Use `[section title](#section-title)`. <br>
# EG: [Section Link for Intro](#Intro)
# ***
#
# ## Hotkeys
# *For PC*<br>
# _Command Palette_:  `CTRL + SHIFT + P`<br>
# *For MAC* <br>
# _Command Palette_:  `Cmd + Shift + P`<br>
# _Change to Markdown_: `m`<br>
# _Change to Code_: `y`<br>
# _Cell creation_: `a` to insert aa new cell above current. `b` to insert below. <br>
# _Cell editing_: `x, c, v, d, z` <br>
# _Delete current cell_: `d + d`<br>
# _Split current cell into two_: `Ctrl + Shift + -`<br>
# _Find and replace on your code_: `ESC + f`<br>
# _Toggle cell output_: `Esc + O`<br>
# ***
#
# ## Inputting LaTeX
#
# Use __$$__ to create centered paragraph in display mode or __\$__ in line outputs. <br> EG:
#
# $$ Classification Rate = \frac1N \sum_{i=0}^n I(y_i = \hat{y_i}) $$ <br>
#
# Or inline outputs: <br>
#
# $ bmi\_index = \beta_0 + \beta_1 \cdot X_i + \epsilon $
# ***
#
# ## Important Notes <br>
# *To add little spacing in display mode use \ <br>
# *To add a new line when in math display mode use `\\` <br>
# *To display fraction use `\frac{arg 1}{arg 2}` <br>
# *For Power (superscripts text) use `^{}` <br>
# *For indices (subscripts) use `_{}` <br>
# *For roots use `\sqrt[n]{arg} <br>
# *The [n] is optional <br>
# ***
#
# ## Greek Letters
# Use `\` to create greek letters. Capitalization also works
# ***
#
# ## Mathematical Symbols
# ![math.webp](Desktop/math.webp).
# ***
#
# ## Magic Commands in Jupyter Notebooks
# __Line Magics__: Uses `%` prefix and work on a single line of input. <br>
# __Cell Magics__: Uses `%%` prefix and work on multiple lines. <br>
#
# * `%lsmagic` - Return a list all magic command <br>
# * `%run` - Execute external python script<br>
# * `%load` - Load in a local file, URL, function, or class <br>
# * `%who` - Return <br>
# * `%matplotlib notebook` - Allow you to interactively work with plots from `matplotlib`. <br>
# * `%matplotlib inline` - Allow you to disable interactivity with plots. <br>
# * `%%time` - Show the time it took to execute the line of code. Good for checking efficiency. <br>
# ***
#
# ## Pretty Displays
#
# Use `from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"`
# ***
#
# ## Suppress outputs
# Use `;` to surpress the output and show only the plot.
# ***
#
# ## Select more than one row
# Use `Alt + mouse click`

# %% [markdown]
# # PYTHON NOTES
# ***
#
# ## Sequence Operations
# `s.index[x[,i [,j ]]`: We can use operations such as `s.insert.index[x[,i[,j]]` to insert into an array positionally. <br>
# ***
#
# ## List Operations
# `len(list)`: Measures length of list <br>
# `list_name[indexposition]`: Returns element in ref position. <br>
# `list_name[-1]`: returns the last element in the list <br>
# `list_name[0]`: First element in the list <br>
# `list_name[start:end]`: To slice the list <br>
# `list_name[-3:]`: To select the last 3 elements <br>
# `list_name[2:]` : To select first 2 elements <br>
# `list_name.count('string' or 'int)`: To count all the recurrences of the reference. <br>
# `list_name.sort()`: To sort alphabetically (for strings) <br>
# `sorted(list_name)`: Comes before a list and generates a new list. <br>
# `zip(lists,lists2)`: Combines two lists into tuples. <br>
# ***
#
# ## Tuples
# ### Unpacking Tuples
# * We are able to unpack tuples using the following code `var_1, var_2, var_3 = tuple` where `tuple = (val_1, val_2, val_3)`
# <br>
# * Creating a one element tuple just outputs a single value. This is because paranthesis are used to surround certain expressions. To create one element tuple use: `(val_1,)` <- a trailing comma.
# <br>
# * Tuples are immutable. Usually used for data that is meant to be grouped together but are not the same data. Order matters.
# <br>
# ***
#
# ## Loops
# ### For loops
# __For Loop list__: `For i in LIST: print list_item`: Prints item in the list for each index in the list. <br>
# __Iterative Loop__: `For i in range(x,y): print string`: Prints string each time i is in the value between x and y <br>
# __Breaks__: `For i in list: print(list_element) if list_element = x: break`: Break is indented after if. <br>
# __Continue__: Lets us skip through iterations that we don't want. eg: ```big_number_list = [1, 2, -1, 4, -5, 5, 2, -9]
# for i in big_number_list:
#   if i < 0:
#     continue
#   print(i)```
# ***
#
# ### While Loops
# * Usually defines a variable before the loop. This is to reiterate the loop on that variable.
# Example Code:
# ```index = 0
# while index < len(dog_breeds):
#   print(dog_breeds[index])
#   index += 1
# ```
# ***
#
# ### Nested Loops
# EG: <br>
# ```
# for team in project_teams:
#   for student in team:
#     print(student)
#
# ```
# ***
# ### List Comprehensions
#
# ```
# This list comprehension:
#
# * Takes an element in words
# * Assigns that element to a variable called word
# * Checks if word[0] == '@', and if so, it adds word to the new list, usernames. If not, nothing happens.
# * Repeats steps 1-3 for all of the strings in words
# ```
# <br>
#
# ```
# Other Examples:
#
# * Takes a string in usernames
# * Assigns that string to a variable called user
# * Adds “ please follow me!” to user
# * Appends that concatenation to the new list called messages
# * Repeats steps 1-4 for all of the strings in usernames
# ```
#
# Example Code: `updated_upvotes = [vote_value + 100 for vote_value in my_upvotes]` <br>
#
# Example Code: In order to find the products in each nested list.
# ```
# nested_lists = [[4, 8], [15, 16], [23, 42]]
#
# product = [num1*num2 for (num1,num2) in nested_lists]
# ```
# __Example Code__: For creating a list comprehension with operations within tuples and two different lists:
# ```
# a = [1.0, 2.0, 3.0]
# b = [4.0, 5.0, 6.0]
# sums = [item1 + item2 for (item1, item2) in zip(a, b)]
# ```
# ***
#
#
# ## Looping Techniques
#
# Click [here](https://docs.python.org/3/tutorial/datastructures.html#looping-techniques) for looping techniques.
# ***
#
# ## Strings
#
# * Can slice strings using `string_value[beginning_index : ending_index]`
# * Note that 0 index begins BEFORE the first letter. As you iterate, you move past the 0 and to 1, at which point you've iterated over the first letter.
# * Using a len() statement as the starting index and omitting the final index lets you slice n characters from the end of a string, where n is the amount you subtract from len().
#
# __Example Code__:
# ``` length = len(favorite_fruit)
# last_chars = favorite_fruit[length-4:]
# print(last_chars)
#  ```
#
# * Negative indices count backwards from the string (AKA iterates backwarwards).
# * To imitate len() function:
#
# __Example Code__:
#
# ```
# def get_length(word):
#   counter = 0
#   for letter in word:
#     counter += 1
#   return counter
# ```
# ***
#
# ### String Methods
#
# `string_name.string_method(arguments)`
#
# * `len()` called a string as its argument whereas the string_method is called at the end of a string and each has its own method specific arguments.
#
# ### String Methods - Formatting
# `.lower()`, `.upper()`, `.title()`
#
# ### String Methods - Splitting Strings
# `.split()`: Also known as the delimiter. Default is to split by the spaces.
# * Returns each string between each split into a list * The argument removes the argument values from the string and returns all string segments between splits.
# <br>
#
# __A good example of using split:__
#
# <br>
# Get the last names of a list:
#
# ```
# author_last_names = []
# for i in author_names:
#   author_last_names.append(i.split()[-1])
# print(author_last_names)
# ```
# __Escape Sequences__
#
# Used to escape sequences. The below are arguments for the `.split(argument)` function.
#
# `\n`: Newline. Creates a list that splits any multiline string and creates a new element for each line in the string.
#
# `\t`: Horizontal Tab
#
# ### String Methods - Joining Strings
# `delimiter.join(string)`: Essentially opposite of split. Joins strings by the delimiter selected. <br>
#
# For Example:
#
# ```
# my_munequita = ['My', 'Spanish', 'Harlem', 'Mona', 'Lisa']
# print(' '.join(my_munequita))
# ```
# Note that we can also use escape sequences for the delimiter.
#
# For Example:
#
# ```
# '\n'.join(smooth_fifth_verse_lines)
# ```
#
# Which essentially joins the strings and sets a new line sequentially for each element in the list.
#
# ### String Methods - .strip()
#
# White space in between strings is preserved, however spaces on the ends of all strings is removed.
#
# `string_name.strip(delimiter)`
#
# We can choose a delimiter to strip from the string. If we leave it empty, it removes all spaces that are not between two strings.
#
# __You must iterate through each element to strip it. You cannot strip a list of strings__
#
# ### String Methods - .replace()
#
# `string_name.replace(character_being_replaced, new_character)`
#
# ### String Methods - .find()
#
# `string_element.find(string_to_find)`
#
# Returns the _index value_ where the string is located.
#
# ### String Methods - .format()
#
# ```
# def favorite_song_statement(song, artist):
#   return "My favorite song is {} by {}.".format(song, artist)
# ```
#
# Takes the variable as an argument and includes them in the string that it is run on where `{}` are used as placeholders for the variables.
#
# For legibility,
#
# We can use the following _keywords_:
#
# ```
# def favorite_song_statement(song, artist):
#     return "My favorite song is {song} by {artist}.".format(song=song, artist=artist)
# ```
#
# If we want to iterate on multiple indexes at once we can do the following:
#
# ```
# titles = []
# poets = []
# dates = []
# for poem in highlighted_poems_details:
#   titles.append(poem[0])
#   poets.append(poem[1])
#   dates.append(poem[2])
#
# for i in range(len(titles)):
#   title, poet, date = titles[i], poets[i], dates[i]
#
#   print("The poem {} was published by {} in {}".format(title, poet,date))
#
# ```
#
# ### Common String Operations Documentation
#
# Click [here](https://docs.python.org/3/library/string.html) for documentation.
#
# ### Special notes about Boolean Expressions and Strings:
#
# Note the following problem:
#
# ```
# Create a function called x_length_words that takes a string named sentence and an integer named x as parameters. This function should return True if every word in sentence has a length greater than or equal to x.
# ```
#
# A key note is that we require a function that delimits the sentence into a list and iterates through the list, which will return false if len(word) > x. One way to think about it is that we can use a counter to count the number of times that True or False are returned. If counter != len(words), return True, else False. Potentially works but, the smarter way is this:
#
# ``
# def x_length_words(sentence, x):
#   words = sentence.split(" ")
#   for word in words:
#     if len(word) < x:
#       return False
#   return True
# ``
#
# Why is this smarter? Because the for loop iterates over `words` and if any of the elements in the list fails the if statement, it then passes to be true, at which point the whole function returns true. The only way for this function to return false is if every single element is false. This is very similar to an 'or' statement in a more implicit way. For each iteration in `words`, the function passes the if statement. The for loop part is always true, unless every pass through the if statement is false.
#
# ### Every Other Letter Problem
#
# ```
# Create a function named every_other_letter that takes a string named word as a parameter. The function should return a string containing every other letter in word.
# ```
#
# Remember here that `range(beg inclusive, ending exclusive, pattern)` will allow you to skip indexes by setting pattern == 2.
#
# ## Dictionary
# ---
#
# Click [here](https://docs.python.org/3/tutorial/datastructures.html?fbclid=IwAR0nNA7sGCXg-n0AafPn9W5xz4aU5tJ_Odg5GJHZ1X5BLhd7vrDNCjwHU20#dictionaries) for documentation.
#
# Unordered set of key value pairs. For example
#
# `Variable_name = {"string":value, "string":value ....}`
#
# We can also map number to other numbers in a dictionary.
#
# `Variable_name = {num1:num2, num3:num4.... }`
#
# Could also be string keys to string values.
#
# Dictionaries rely on each key having a _hash value_. This is a specific identifier for the key.
#
# Therefore, we cannot have lists:
#
# `dictionary = {[list 1]:value, [list2]:value...}`
#
# However, the lists can be values:
#
# `dictionary = {key : [list] ...etc}`
#
# ### Adding a Key to A Dictionary
#
# `dictionary[key] = value`
#
# ### Adding Multiple Keys to A Dictionary
#
# `dictionary.update({key:value, key:value})`
#
# ### Overwriting keys
#
# Simply just add the key or add multiple keys and will replace the value associated with the duplicated key.
#
# ### List Comprehensions to Dictionaries
#
# For example, you have two lists:
#
# `List 1 = [strings..]`
# `list 2 = [integers..]`
#
# Using list comprehension we can combine the two:
#
# `dictionary = {key:value for key, value in zip(names, heights)}`
#
# ### Using if to print out a specific value using a key:
#
# `if key_item in dictionary:
#     print(value)`
#
# ### Try/Except to Get a Key
#
# `Key_to_check = "key_name"
#     try:
#         print(dictionary[key_to_check])
#     except KeyError:
#         print("That key doesn't exist!")`
#
# ### Safely Get a Key
#
# Since we can't always predict all the keys to be called and what to respond, we can use `.get()`.
#
# `dictionary.get(key, default value)`
#
# ### Delete a Key
#
# `dictionary.pop(value, default)`
#
# ### Get all Keys
#
# The `.keys()` method retursn the dict_keys object. Object is a view object. To view all keys:
#
# `variable_name = dict_name.key()`
#
# The value is going to be a view objecting and in the form of dict_key(\[key_1, key_2, key_3...\])
#
# or if we want to iterate through the keys and print them: '
#
# `for i in dict.keys();
#     print(key)
# `
#
# ### Get all Values
#
# `.values()` returns all dict_values in a view object.
#
# It can be used in place of a list for iteration.
#
# For example, to print all the lists in order:
#
# `for i in dict.values():
#     print(i)
# `
#
# if `dict = {key:list1 , key:list2, ... etc}`
#
# The output will be:
#
# `[list 1]
#  [list 2]
#  [list 3]
# ....
# `
# The again we can use:
#
# `list(test_scores.value())` to get all the values in a list.
#
# Usually the dict_list is enough usually.
#
# ### Get all items
#
# Use `.items()`
#
# To iterate and output a tuple:
#
# `for x,y in dict.items():
#     print(key ..... value....)
# `
#
# ### Zip and Tuples
#
# Say we have two lists:
#
# `List1 = [x,y,z]
# List 2 = [1,2,3,]
# `
# We want to create a dictionary where the keys are the elements in list 1 and the values are the elements in list two.
#
# We do the following:
#
# `Create_new_list = {}
# for list_1_element, list_2_element in zip(List1, List2):
#     names_to_ages[name] = age
# `
# ***
#
# # Types
#
# ## Floats, int, list, dict...type()
#
# Use `type()` to find what type a variable is.
#
# ## Class
#
# Is a template for a data type. It describes the kinds of information that class will hold and how a programmer will interact with that data.
#
# __CAPITALIZE FIRST LETTERS OF CLASSES BY BEST PRACTICE__
#
# To define a class:
#
# `class CoolClass:
#     pass`
#
# Need to write pass to avoid Indentation error. This is called making an _empty class_.
#
# ## Instantiation
#
# Classes must be instantiated => Create an instance of the class.
#
# To create an instance of the class, use:
#
# `cool_instance = CoolClass()`
#
# ***
#
# # Object-Oriented Programming
#
# Class instance = Object
#
# The pattern of defining classes and creating objects to represent the responsibilities of a program is called OOP.
#
# Instantiation takes a class and turns it into an object.
#
# Type function does the opposite, when called it returns the class of the object.
#
# Note that `type()` provides the class if we use an instance in the argument (since an instance is what turned a class into an object).
#
# ## Class Variables
#
# If we want the same data to be available to every instance of the class, we use class variables. This is a variable that is the same for every instance of the class.
#
# Access all object's class variables with `object.variable`.
#
# Syntax:
#
# ```
# class Musician:
#   title = "Rockstar"
#
# drummer = Musician()
# print(drummer.title)
# # prints "Rockstar"
# ```
#
# Above we defined the class Musician, then instantiated drummer to be an object of type Musician. We then printed out the drummer’s .title attribute, which is a class variable that we defined as the string “Rockstar”.
#
# ## Methods
#
# Methods are functions that are defined as part of a class. The first argument in a method is always the object that is calling the method. Convention recommends that we name this first argument self. Methods always have at least this one argument.
#
# How to define methods:
#
# ```
# class Dog:
#   dog_time_dilation = 7
#
#   def time_explanation(self):
#     print("Dogs experience {} years for every 1 human year.".format(self.dog_time_dilation))
#
# pipi_pitbull = Dog()
# pipi_pitbull.time_explanation()
# # Prints "Dogs experience 7 years for every 1 human year."
# ```
#
# Above we created a Dog class with a time_explanation method that takes one argument, self, which refers to the object calling the function. We created a Dog named pipi_pitbull and called the .time_explanation() method on our new object for Pipi.
#
# Notice we didn’t pass any arguments when we called .time_explanation(), but were able to refer to self in the function body. When you call a method it automatically passes the object calling the method as the first argument.
#
# For a method to take `self` and return a string, refer to:
#
# ```
# class Rules:
#   def washing_brushes(self):
#     return "Point bristles towards the basin while washing your brushes."
# ```
#
# ## Constructors
#
# Also called dunder methods.
#
# First dunder method: `__init__()`: Used to initialize newly created object. Call it to instantiate it.
#
# EG:
#
# ```
# class Shouter:
#     def __init__(self):
#         print("HELLO?!")
# shout1 = Shouter()
# shout2 = Shouter()
# ```
# Everytime we create an instance of shouter (The class), we print out a shout.
#
# Basically, blueprint and then everytime we make run through the blueprint and execute it (create an instance), we get the result of our plan which may have a method.
#
# Can add more parameters to init:
#
# ```
# class Shouter:
#   def __init__(self, phrase):
#     # make sure phrase is a string
#     if type(phrase) == str:
#
#       # then shout it out
#       print(phrase.upper())
#
# shout1 = Shouter("shout")
# # prints "SHOUT"
#
# shout2 = Shouter("shout")
# # prints "SHOUT"
#
# shout3 = Shouter("let it all out")
# # prints "LET IT ALL OUT"
# ```
#
# ## Instance Variables
#
# Data type specific to the instance that it is assigned to.
#
# The data held by an object is referred to as an instance variable. Instance variables aren’t shared by all instances of a class — they are variables that are specific to the object they are attached to.
#
# `parameter.instance_variable`
#
# ## Attribute Functions
#
# `hasatter(object, attribute)`: Object is the object we are testing to see if it has an attribute. Attribute is the name of the attribute we want to see if it exists. _output_ is BINARY.
#
# `getattr(object, attribute, default)`: Same, except a defualt value given.
#
# returns `True` if an object has a given attribute and `False` otherwise. If we want the attribute of a value then use `getattr()`. Third argument of `getattr()` will provide a default value.
#
# ## Self
#
# `self.object` refers to the object and not the class being called.
#
# ```
# class Circle:
#   pi = 3.14
#   def __init__(self, diameter):
#     print("Creating circle with diameter {d}".format(d=diameter))
#     # Add assignment for self.radius here:
#
#     self.radius = diameter / 2
#
#   def circumference(self):
#     return 2 * self.pi * self.radius
#
# medium_pizza = Circle(12)
# teaching_table = Circle(36)
# round_room = Circle(11460)
#
# print(medium_pizza.circumference())
# print(teaching_table.circumference())
# print(round_room.circumference())
# ```
#
# ## Everything is an object
#
# `dir()` to investigate an object's attributes at run time.
#
# Note functions are objects too
#
# ## String Representation
#
# Using a new dunder method called `__repr__()`, which assigns a string representation of the class to be. Can only have parameter `self`.
#
# We can use `__repr__()` the following way:
#
# ```
# class Circle:
#   pi = 3.14
#
#   def __init__(self, diameter):
#     self.radius = diameter / 2
#
#   def area(self):
#     return self.pi * self.radius ** 2
#
#   def circumference(self):
#     return self.pi * 2 * self.radius
#
#   def __repr__(self):
#     return "Circle with radius {radius}".format(radius = self.radius)
#
# medium_pizza = Circle(12)
# teaching_table = Circle(36)
# round_room = Circle(11460)
#
# print(medium_pizza)
# print(teaching_table)
# print(round_room)
# ```
# ## INSTALLING MODULES
#
# Also referred to as "Libraries" or "Packages".
#
# `from module_name import
#  object_name`
#
# # PACKAGE LIST
#
# DATE TIME: `import datetime from datetime`
# RANDOMIZER: `import random`, with functions such as `random.choice` and `random.randit()`.
#
# # Modules Python Namespaces
#
# Basically when the package (namespace) goes prior to a function called in the package. EG:
# `random.randint()`, function is `randint()` and `random` is the package.
#
# We can select the namespace by...
#
# `import module_name as name_you_pick`
#
# To import a specific module/function:
#
# `from matplotlib import pyplot as plt`
#
# # TO CREATE RANDOM SAMPLE
#
# `random.sample(range(1000), 12)`
#
# Where the arguments are `(range, sample size)`

# %%
from matplotlib import pyplot as plt

import random as random

numbers_a = range(1,13)

numbers_b = random.sample(range(1000), 12)

plt.plot(numbers_a, numbers_b)

plt.show()

# %% [markdown]
# # Modules Python Decimals
#
# We want a data type that performs decimal arithmetic more accurately. There is an error if we use python-built in 0.10 + 0.35 = 0.4499999999996 so we need a decimal.
#
# ```
# from decimal import Decimal
#
# cost_of_gum = Decimal('0.10')
# cost_of_gumdrop = Decimal('0.35')
# ```
#
# # Scope
#
# We can import functions from other sheets by using
#
# `from other_sheet import function_name`
#
# # Modules Documentation
#
# [Click Here](https://docs.python.org/3/tutorial/modules.html)

# %% [markdown]
# # Datetimes Module
#
# Datetime is a python object showing a point and time.
#
# 1. Importing datetime module
# `from datetime import datetime`
# 2. Creating a day
# EG: `birthday = datetime(year, month, day, hours, minutes, seconds, milleseconds, timezones)`
# 3. To access each arguments
# `birthday.year
# birthday.month
# birthday.hour
# birthday.weekday()`
# We note that weekday indexes from monday = 0.
# 4. Using datetime.now()
# `datetime.now()` tells us the exact day this exact moment.
# 5. Use math operators on datetime
# `datetime(2018, 1, 1) - datetime(2017,1,1)`
# Will tell us
# `#datetime.timedelta(days=365)`
# 6. Parse date time out of string.
# strptime will parse a string to find a date.
# For example, date may be written as 'Jan 15, 2018'. We can parse the date using:
#
# `parsed_date = datetime.strptime(string , formatted string)`
#
# Where the formatted string will tell us which part of the spring is day, month, or year.
#
# [CLICK HERE FOR DATETIME BEHAVIOUR](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior)
#
# 7. datetime.strptime()
# p basically means parse and parses through a string and translate to datetime.
# EG: `parsed_date = datetime.strptime('Jan 15, 1996', '%b, %d, %Y')`
#
# 8. datetime.strftime()
# Takes a datetime and allows us to grab certain parts to output a string.
#
# EG: `date_string = datetime.strftime(datetime, formatted_string)`.
#
# Basically opposite of datetime.strptime.
#
# EG: `date_string = datetime.strftime(datetime.now(), '%b %d, %Y')`

# %% [markdown]
# # Setting Up Virtual Environments PIPENV
#
#
# Essentially, sometimes we need access to older versions of libraries but the newest version is installed globally.
#
# To set up, watch video!
#
# The file viewer/folder has to be the same folder that is opened in the terminal.
#
# # Using pipenv
#
# 1. Initialize Virtual Environment
#
# `pipenv --three` will be initialize VE to python 3.
#
# We may have two different project folders/directories.
#
# We first can create a virtual environment in one of the project files using:
#
# `cd directory_name`
#
# Make sure however, that the project we're using in our editor is using a directory that is a parent director to the other directories.
#
# 2. Setting Up Different Dependencies
#
# We first note that when we install, without specifying version, any library, we will see `package_name = '*'` in the pipfile. It will create a pipfile.lock file that will lock any verison that we install.
#
# To install a different version:
#
# `pipenv install requests==2.18.1` for example.
#
# 3. Switching To A Different Project
#
# `cd ../project-2`
#
# 4. To use the VE, use PIPENV SHELL
#
# We need to `pipenv shell` in terminal in order to use the virtual environment.
#
# We can write `python3` in order to operate in python.
#
# To exit the shell, just write exit, then exit() or ctrl D.
#
# # Reading a File
#
# How do we read different files using Python?
#
# For example, we have the file real_cool_document.txt
#
# we could read the file with:
#
# ```
# with
# open('real_cool_document.txt') as cool_doc: cool_contents = cool_doc.read()
# print(cool_contents)
# ```
# Essentially, we open the file as a variable name, then assign the variable to the string that is read out by cool_doc.read() and print the variable.
#
# # Iterating Through Lines
#
# If we want to store each line in a text file in a variable?
#
# Use: `readlines()`
#
# For example:
#
# ```
# with open('keats_sonnet.txt') as keats_sonnet:
#   for line in keats_sonnet.readlines():
#     print(line)
# ```
#
# Essentially points to the file and iterates over each line in the document and prints the file out.
#
# # Reading a line
#
# To read a single line at a time....
#
# ```
# with open('millay_sonnet.txt') as sonnet_doc:
#   first_line = sonnet_doc.readline()
#   second_line = sonnet_doc.readline()
#   print(second_line)
# ```
#
# This script also creates a file object called sonnet_doc that points to the file millay_sonnet.txt. It then reads in the first line using sonnet_doc.readline() and saves that to the variable first_line. It then saves the second line (So make the most of this, your little day,) into the variable second_line and then prints it out.
#
# # Writing a file
#
# ```
# with open('generated_file.txt', 'w') as gen_file:
#   gen_file.write("What an incredible file!")
# ```
#
# Here we pass the argument 'w' to open() in order to indicate to open the file in write-mode. The default argument is 'r' and passing 'r' to open() opens the file in read-mode as we’ve been doing.
#
# # Appending to a File
#
# ```
# with open('generated_file.txt', 'a') as gen_file:
#   gen_file.write("... and it still is")
# ```
#
# In the code above we open a file object in the temporary variable gen_file. This variable points to the file generated_file.txt and, since it’s open in append-mode, adds the line ... and it still is as a new line to the file.
#
# If we were to run the code again, we would continue appending to the same file.
#
# # Why use WITH?
#
# We’ve been opening these files with this with block so far, but it seems a little weird that we can only use our file variable in the indented block. Why is that? The with keyword invokes something called a context manager for the file that we’re calling open() on. This context manager takes care of opening the file when we call open() and then closing the file after we leave the indented block.
#
# Without with, we would have to manually close the file using `file_name.close()`.
#
# # What is a CSV File?
#
# Means Comma - Separated Values
#
# We open CSV files the same way we open txt files.
#
# Notice that the first row of the CSV file doesn’t actually represent any data, just the labels of the data that’s present in the rest of the file. The rest of the rows of the file are the same as the rows in the spreadsheet software, just instead of being separated into different cells they’re separated by… well I suppose it’s fair to say they’re separated by commas.
#
# # Convert CSV using DictReader
#
# ```
# import csv
#
# list_of_email_addresses = []
# with open('users.csv', newline='') as users_csv:
#   user_reader = csv.DictReader(users_csv)
#   for row in user_reader:
#     list_of_email_addresses.append(row['Email'])
# ```
#
# In the above code we first import our csv library, which gives us the tools to parse our CSV file. We then create the empty list list_of_email_addresses which we’ll later populate with the email addresses from our CSV. Then we open the users.csv file with the temporary variable users_csv.
#
# We pass the additional keyword argument newline='' to the file opening open() function so that we don’t accidentally mistake a line break in one of our data fields as a new row in our CSV (read more about this in the Python documentation).
#
# After opening our new CSV file we use csv.DictReader(users_csv) which converts the lines of our CSV file to Python dictionaries which we can use access methods for. The keys of the dictionary are, by default, the entries in the first line of our CSV file. Since our CSV’s first line calls the third field in our CSV “Email“, we can use that as the key in each row of our DictReader.
#
# When we iterate through the rows of our user_reader object, we access all of the rows in our CSV as dictionaries (except for the first row, which we used to label the keys of our dictionary). By accessing the 'Email' key of each of these rows we can grab the email address in that row and append it to our list_of_email_addresses.
#
# # Delimiters
#
# ```
# import csv
#
# with open('addresses.csv', newline='') as addresses_csv:
#   address_reader = csv.DictReader(addresses_csv, delimiter=';')
#   for row in address_reader:
#     print(row['Address'])
# ```
#
# So we call all files with a list of different values a CSV file and then use different delimiters (like a comma or tab) to indicate where the different values start and stop.
#
# The reason we use `newline=''` as an argument in the `open()` statement is the possibility of a new line escaped by `\n`.
#
# # Writing a CSV File
#
# If we have data and want to write into a CSV file...
#
# ```
# big_list = [{'name': 'Fredrick Stein', 'userid': 6712359021, 'is_admin': False}, {'name': 'Wiltmore Denis', 'userid': 2525942, 'is_admin': False}, {'name': 'Greely Plonk', 'userid': 15890235, 'is_admin': False}, {'name': 'Dendris Stulo', 'userid': 572189563, 'is_admin': True}]
#
# import csv
#
# with open('output.csv', 'w') as output_csv:
#   fields = ['name', 'userid', 'is_admin']
#   output_writer = csv.DictWriter(output_csv, fieldnames=fields)
#
#   output_writer.writeheader()
#   for item in big_list:
#     output_writer.writerow(item)
# ```
#
# In our code above we had a set of dictionaries with the same keys for each, a prime candidate for a CSV. We import the csv library, and then open a new CSV file in write-mode by passing the 'w' argument to the open() function.
#
# We then define the fields we’re going to be using into a variable called fields. We then instantiate our CSV writer object and pass two arguments. The first is output_csv, the file handler object. The second is our list of fields fields which we pass to the keyword parameter fieldnames.
#
# Now that we’ve instantiated our CSV file writer, we can start adding lines to the file itself! First we want the headers, so we call .writeheader() on the writer object. This writes all the fields passed to fieldnames as the first row in our file. Then we iterate through our big_list of data. Each item in big_list is a dictionary with each field in fields as the keys. We call output_writer.writerow() with the item dictionaries which writes each line to the CSV file.
#
# # Reading a JSON File
#
# ```
# import json
#
# with open('purchase_14781239.json') as purchase_json:
#   purchase_data = json.load(purchase_json)
#
# print(purchase_data['user'])
# # Prints 'ellen_greg'
# ```
#
# Creates a dictionary out of the file. Saves the file to purchase_data and prints out one of the values of the JSON file by keying into the purchase_data object.
#
# # Save data into aa JSON File
#
# ```
# turn_to_json = {
#   'eventId': 674189,
#   'dateTime': '2015-02-12T09:23:17.511Z',
#   'chocolate': 'Semi-sweet Dark',
#   'isTomatoAFruit': True
# }
#
# import json
#
# with open('output.json', 'w') as json_file:
#   json.dump(turn_to_json, json_file)
# ```
#
# Where we note `.dump()` takes two arguments: first the data object that we're turning into a JSON file, then the file object we want to save.
#
# # FOR READING AND WRITING FILES DOCUMENTATION
#
# [CLICK HERE](https://docs.python.org/3/tutorial/inputoutput.html#reading-and-writing-files)
